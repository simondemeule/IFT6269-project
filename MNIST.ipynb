# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join('../src/')))
from f_gan import *

# Enable Jupyter notebook plotting
# %matplotlib inline

# Load in binarized MNIST data, separate into data loaders
train_iter, val_iter, test_iter = get_data()

# Init model
model = fGAN(image_size=784,
             hidden_dim=400,
             z_dim=20)

# Init trainer
trainer = fGANTrainer(model=model,
                      train_iter=train_iter,
                      val_iter=val_iter,
                      test_iter=test_iter,
                      viz=True)

# Train
trainer.train(num_epochs=25,
              method='total_variation',
              G_lr=1e-4,
              D_lr=1e-4,
              D_steps=1)

# Show loss
trainer.viz_loss()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch[1/25], G Loss: -0.0407, D Loss: -0.2477
#   4%|▍         | 1/25 [00:04<01:37,  4.08s/it]
# Epoch[2/25], G Loss: -0.0435, D Loss: -0.2757
#   8%|▊         | 2/25 [00:09<01:48,  4.72s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7c81520e0cef> in <module>
#      26               G_lr=1e-4,
#      27               D_lr=1e-4,
# ---> 28               D_steps=1)
#      29
#      30 # Show loss
#
# /media/frederic/IFT6269/f_gan.py in train(self, num_epochs, method, G_lr, D_lr, D_steps)
#     198
#     199                     # Reshape images
# --> 200                     images = self.process_batch(self.train_iter)
#     201
#     202                     # TRAINING D: Zero out gradients for D
#
# /media/frederic/IFT6269/f_gan.py in process_batch(self, iterator)
#     289     def process_batch(self, iterator):
#     290         """ Generate a process batch to be input into the Discriminator D """
# --> 291         images, _ = next(iter(iterator))
#     292         images = to_cuda(images.view(images.shape[0], -1))
#     293         return images
#
# KeyboardInterrupt:

# %%
import torchvision
