# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join('../src/')))
from f_gan import *

# Enable Jupyter notebook plotting
# %matplotlib inline

# Load in binarized MNIST data, separate into data loaders
train_iter, val_iter, test_iter = get_data()

# Init model
model = fGAN(image_size=784,
             hidden_dim=400,
             z_dim=20)

# Init trainer
trainer = fGANTrainer(model=model,
                      train_iter=train_iter,
                      val_iter=val_iter,
                      test_iter=test_iter,
                      viz=True)

# Train
trainer.train(num_epochs=25,
              method='total_variation',
              G_lr=1e-4,
              D_lr=1e-4,
              D_steps=1)

# Show loss
trainer.viz_loss()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch[1/25], G Loss: -0.0407, D Loss: -0.2477
#   4%|▍         | 1/25 [00:04<01:52,  4.68s/it]
# Epoch[2/25], G Loss: -0.0435, D Loss: -0.2757
#   8%|▊         | 2/25 [00:09<01:45,  4.60s/it]
# Epoch[3/25], G Loss: -0.1215, D Loss: -0.2007
#  12%|█▏        | 3/25 [00:13<01:36,  4.40s/it]
# Epoch[4/25], G Loss: -0.1263, D Loss: -0.1948
#  16%|█▌        | 4/25 [00:16<01:29,  4.26s/it]
# Epoch[5/25], G Loss: -0.0917, D Loss: -0.2129
#  20%|██        | 5/25 [00:21<01:26,  4.31s/it]

# %%
import torchvision
